# %% [markdown]
# # 🔹 Sabriya Sowers' Titanic Dataset Analysis 🔹
#
# **Author:** Sabriya Sowers
# **Date:** October 30, 2025

# %% [markdown]
# ## Introduction
#
# This project uses the **Titanic dataset** from the Seaborn library to explore key steps in data analysis. The workflow includes loading and inspecting the data, identifying missing values, summarizing key statistics, exploring feature relationships through visualizations, and preparing the dataset for classification modeling.

# %% [markdown]
# ## Section 1. Import and Inspect the Data

# %%
# imports all at the top
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# Load dataset from seaborn
titanic = sns.load_dataset("titanic")

# %%
# Displays basic dataset info (e.g., total rows, features)
titanic.info()

# Displays the first 10 rows of dataset
print(titanic.head(10))

# Shows me how many missing (null) values there are in each column of the Titanic dataset
titanic.isnull().sum()

# Displays summary statistics
print(titanic.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB
# ...

# %%
# Check for correlations
print(titanic.corr(numeric_only=True))
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %% [markdown]
# ## Reflection 1

# %% [markdown]
# ## Section 1. Import and Inspect the Data

# %% [markdown]
# ## 2.1 Explore Data Patterns and Distributions

# %% [markdown]
# ## 2.2 Handle Missing Values and Clean Data

# %% [markdown]
# ## 2.3 Feature Engineering

# %% [markdown]
# ## Section 3. Feature Selection and Justification

# %% [markdown]
# ## Section 4. Splitting

# %% [markdown]
# Basic Train/Test split

# %% [markdown]
# Stratified Train/Test split

# %% [markdown]
# ## Compare Results
